# %%
# 1. LOADING LIBRARIES

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 2. LOADING THE DATASET FROM A CSV FILE

# %%
df = pd.read_csv("mpesa_fraud_detection_dataset.csv")

# %%
# 3. EXPLORATORY DATA ANALYSIS

# %%
# Displaying the first 10 records

# %%
df.head(10)
# Out:
#   TransactionID  Amount SenderCounty ReceiverCounty  TimeOfDay  \
# 0     TXN000001  335293      Mombasa          Nyeri          2
# 1     TXN000002   16713        Nyeri         Nakuru         22
# 2     TXN000003  115624     Machakos         Kiambu          4
# 3     TXN000004  400340     Machakos           Meru          8
# 4     TXN000005  382639         Meru       Machakos         18
# 5     TXN000006  369448      Mombasa    Uasin Gishu          8
# 6     TXN000007  333331       Kiambu        Mombasa         19
# 7     TXN000008  280093        Nyeri         Nakuru         21
# 8     TXN000009  441947  Uasin Gishu         Kiambu          2
# 9     TXN000010  478796     Kakamega         Kisumu          8
#
#   TransactionType  AccountAgeMonths  TransactionsLast24Hours  \
# 0        Withdraw                15                        1
# 1        Withdraw                 4                        3
# 2         Paybill                58                       19
# 3      Send Money                44                        4
# 4         Paybill                59                       18
# 5        Withdraw                 9                        2
# 6         Paybill               107                       12
# 7            Till                94                        8
# 8         Paybill                99                       25
# 9         Paybill                73                       29
#
#   DeviceChangedRecently NewLocationLogin  FailedPinAttempts IsWeekend  \
# 0                    No              Yes                  3       Yes
# 1                   Yes              Yes                  8       Yes
# 2                    No              Yes                  2        No
# 3                   Yes               No                  1        No
# 4                   Yes               No                  1        No
# 5                   Yes               No                  1       Yes
# 6                   Yes               No                  5       Yes
# 7                   Yes               No                  6        No
# 8                   Yes              Yes                  0        No
# 9                    No              Yes                  7        No
#
#   Fraudulent
# 0        Yes
# 1        Yes
# 2         No
# 3         No
# 4         No
# 5         No
# 6        Yes
# 7        Yes
# 8        Yes
# 9        Yes

# %%
# Displaying the last 10 records

# %%
df.tail(10)
# Out:
#      TransactionID  Amount SenderCounty ReceiverCounty  TimeOfDay  \
# 4990     TXN004991  406837         Meru        Nairobi         23
# 4991     TXN004992  345183  Uasin Gishu        Nairobi         16
# 4992     TXN004993  119863  Uasin Gishu    Uasin Gishu         22
# 4993     TXN004994  337045        Nyeri        Nairobi         20
# 4994     TXN004995  178181      Nairobi    Uasin Gishu         20
# 4995     TXN004996  189164       Kiambu         Kiambu          2
# 4996     TXN004997  406287      Mombasa    Uasin Gishu          1
# 4997     TXN004998    6787         Meru        Mombasa         20
# 4998     TXN004999  389058        Nyeri         Kiambu         19
# 4999     TXN005000  124311         Meru        Mombasa          3
#
#      TransactionType  AccountAgeMonths  TransactionsLast24Hours  \
# 4990         Paybill                15                        3
# 4991        Withdraw                84                       22
# 4992        Withdraw               114                       26
# 4993      Send Money                64                       14
# 4994         Paybill               107                       30
# 4995            Till                 7                       23
# 4996            Till                 9                       28
# 4997      Send Money                90                        6
# 4998      Send Money               115                       29
# 4999        Withdraw                18                       27
#
#      DeviceChangedRecently NewLocationLogin  FailedPinAttempts IsWeekend  \
# 4990                   Yes               No                  0       Yes
# 4991                    No               No                  7       Yes
# 4992                   Yes              Yes                  5       Yes
# 4993                   Yes               No                  5       Yes
# 4994                   Yes              Yes                  8       Yes
# 4995                   Yes               No                  5        No
# 4996                   Yes               No                  3        No
# 4997                   Yes               No                  6       Yes
# 4998                    No              Yes                  6        No
# 4999                   Yes               No                  7        No
#
#      Fraudulent
# 4990         No
# 4991         No
# 4992        Yes
# 4993        Yes
# 4994        Yes
# 4995        Yes
# 4996        Yes
# 4997         No
# 4998        Yes
# 4999        Yes

# %%
# Determining the number of rows and columns

# %%
df.shape
# Out:
# (5000, 13)

# %%
# the dataset has 5000 rows and 13 features

# %%
# listing all the features available for analysis

# %%
df.columns
# Out:
# Index(['TransactionID', 'Amount', 'SenderCounty', 'ReceiverCounty',
#        'TimeOfDay', 'TransactionType', 'AccountAgeMonths',
#        'TransactionsLast24Hours', 'DeviceChangedRecently', 'NewLocationLogin',
#        'FailedPinAttempts', 'IsWeekend', 'Fraudulent'],
#       dtype='object')

# %%
# # Data types and non‑null counts

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   TransactionID            5000 non-null   object
#  1   Amount                   5000 non-null   int64
#  2   SenderCounty             5000 non-null   object
#  3   ReceiverCounty           5000 non-null   object
#  4   TimeOfDay                5000 non-null   int64
#  5   TransactionType          5000 non-null   object
#  6   AccountAgeMonths         5000 non-null   int64
#  7   TransactionsLast24Hours  5000 non-null   int64
#  8   DeviceChangedRecently    5000 non-null   object
#  9   NewLocationLogin         5000 non-null   object
#  10  FailedPinAttempts        5000 non-null   int64
#  11  IsWeekend                5000 non-null   object
#  12  Fraudulent               5000 non-null   object
# dtypes: int64(5), object(8)
# memory usage: 507.9+ KB

# %%
# statistical summary  for num columns

# %%
df.describe()
# Out:
#             Amount    TimeOfDay  AccountAgeMonths  TransactionsLast24Hours  \
# count    5000.0000  5000.000000       5000.000000                5000.0000
# mean   251214.9510    11.651000         60.631400                  15.6116
# std    145598.8242     6.944382         34.911856                   8.6213
# min       189.0000     0.000000          1.000000                   1.0000
# 25%    125706.2500     6.000000         31.000000                   8.0000
# 50%    251930.0000    12.000000         60.000000                  15.0000
# 75%    380742.7500    18.000000         91.000000                  23.0000
# max    499956.0000    23.000000        120.000000                  30.0000
#
#        FailedPinAttempts
# count        5000.000000
# mean            3.965400
# std             2.575564
# min             0.000000
# 25%             2.000000
# 50%             4.000000
# 75%             6.000000
# max             8.000000

# %%
df.describe(include = "all")
# Out:
#        TransactionID       Amount SenderCounty ReceiverCounty    TimeOfDay  \
# count           5000    5000.0000         5000           5000  5000.000000
# unique          5000          NaN           10             10          NaN
# top        TXN000001          NaN  Uasin Gishu           Meru          NaN
# freq               1          NaN          536            527          NaN
# mean             NaN  251214.9510          NaN            NaN    11.651000
# std              NaN  145598.8242          NaN            NaN     6.944382
# min              NaN     189.0000          NaN            NaN     0.000000
# 25%              NaN  125706.2500          NaN            NaN     6.000000
# 50%              NaN  251930.0000          NaN            NaN    12.000000
# 75%              NaN  380742.7500          NaN            NaN    18.000000
# max              NaN  499956.0000          NaN            NaN    23.000000
#
#        TransactionType  AccountAgeMonths  TransactionsLast24Hours  \
# count             5000       5000.000000                5000.0000
# unique               4               NaN                      NaN
# top           Withdraw               NaN                      NaN
# freq              1297               NaN                      NaN
# mean               NaN         60.631400                  15.6116
# std                NaN         34.911856                   8.6213
# min                NaN          1.000000                   1.0000
# 25%                NaN         31.000000                   8.0000
# 50%                NaN         60.000000                  15.0000
# 75%                NaN         91.000000                  23.0000
# max                NaN        120.000000                  30.0000
#
#        DeviceChangedRecently NewLocationLogin  FailedPinAttempts IsWeekend  \
# count                   5000             5000        5000.000000      5000
# unique                     2                2                NaN         2
# top                       No               No                NaN        No
# freq                    2513             2515                NaN      2569
# mean                     NaN              NaN           3.965400       NaN
# std                      NaN              NaN           2.575564       NaN
# min                      NaN              NaN           0.000000       NaN
# 25%                      NaN              NaN           2.000000       NaN
# 50%                      NaN              NaN           4.000000       NaN
# 75%                      NaN              NaN           6.000000       NaN
# max                      NaN              NaN           8.000000       NaN
#
#        Fraudulent
# count        5000
# unique          2
# top           Yes
# freq         2754
# mean          NaN
# std           NaN
# min           NaN
# 25%           NaN
# 50%           NaN
# 75%           NaN
# max           NaN

# %%
# identifying numerical columns

# %%
numerical_cols = df.select_dtypes(include = ["int64"])
numerical_cols
# Out:
#       Amount  TimeOfDay  AccountAgeMonths  TransactionsLast24Hours  \
# 0     335293          2                15                        1
# 1      16713         22                 4                        3
# 2     115624          4                58                       19
# 3     400340          8                44                        4
# 4     382639         18                59                       18
# ...      ...        ...               ...                      ...
# 4995  189164          2                 7                       23
# 4996  406287          1                 9                       28
# 4997    6787         20                90                        6
# 4998  389058         19               115                       29
# 4999  124311          3                18                       27
#
#       FailedPinAttempts
# 0                     3
# 1                     8
# 2                     2
# 3                     1
# 4                     1
# ...                 ...
# 4995                  5
# 4996                  3
# 4997                  6
# 4998                  6
# 4999                  7
#
# [5000 rows x 5 columns]

# %%
# identifying categorical columns

# %%
categorical_cols = df.select_dtypes(include = ["object"])
categorical_cols
# Out:
#      TransactionID SenderCounty ReceiverCounty TransactionType  \
# 0        TXN000001      Mombasa          Nyeri        Withdraw
# 1        TXN000002        Nyeri         Nakuru        Withdraw
# 2        TXN000003     Machakos         Kiambu         Paybill
# 3        TXN000004     Machakos           Meru      Send Money
# 4        TXN000005         Meru       Machakos         Paybill
# ...            ...          ...            ...             ...
# 4995     TXN004996       Kiambu         Kiambu            Till
# 4996     TXN004997      Mombasa    Uasin Gishu            Till
# 4997     TXN004998         Meru        Mombasa      Send Money
# 4998     TXN004999        Nyeri         Kiambu      Send Money
# 4999     TXN005000         Meru        Mombasa        Withdraw
#
#      DeviceChangedRecently NewLocationLogin IsWeekend Fraudulent
# 0                       No              Yes       Yes        Yes
# 1                      Yes              Yes       Yes        Yes
# 2                       No              Yes        No         No
# 3                      Yes               No        No         No
# 4                      Yes               No        No         No
# ...                    ...              ...       ...        ...
# 4995                   Yes               No        No        Yes
# 4996                   Yes               No        No        Yes
# 4997                   Yes               No       Yes         No
# 4998                    No              Yes        No        Yes
# 4999                   Yes               No        No        Yes
#
# [5000 rows x 8 columns]

# %%
# 4. DATA CLEANING

# %%
# check for missing values

# %%
missing_values = df.isnull().sum()
missing_values
# Out:
# TransactionID              0
# Amount                     0
# SenderCounty               0
# ReceiverCounty             0
# TimeOfDay                  0
# TransactionType            0
# AccountAgeMonths           0
# TransactionsLast24Hours    0
# DeviceChangedRecently      0
# NewLocationLogin           0
# FailedPinAttempts          0
# IsWeekend                  0
# Fraudulent                 0
# dtype: int64

# %%
# there are no missing values in our dataframe

# %%
# check for duplicate values

# %%
duplicates = df.duplicated().sum()
duplicates
# Out:
# np.int64(0)

# %%
# there are no duplicate values in our dataframe
